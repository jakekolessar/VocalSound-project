# %%
import argparse
import os
import pickle
import sys
from collections import OrderedDict
import time
import torch
import shutil
sys.path.append('/home/jake/repositories/vocalsound/src')
import dataloaders
import models
from traintest import train, validate
import ast
from torch.utils.data import WeightedRandomSampler
import numpy as np

# %%
torch.cuda.empty_cache()

# %%
print("I am process %s, running on %s: starting (%s)" % (
        os.getpid(), os.uname()[1], time.asctime()))
# Out:
# I am process 31471, running on jake-workstation: starting (Fri Jul 15 04:00:39 2022)

# %%
import datetime
from utilities import *
from torch.optim.swa_utils import AveragedModel, SWALR

# %%
def train(audio_model, train_loader, test_loader,
          exp_dir,lr,weight_decay,n_epochs,n_print_steps,save_model): #exp_dir,lr,weight_decay,n_epochs,n_print_steps,save_model
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(device)
    torch.set_grad_enabled(True)
    # Initialize all of the statistics we want to keep track of
    batch_time = AverageMeter()
    per_sample_time = AverageMeter()
    data_time = AverageMeter()
    per_sample_data_time = AverageMeter()
    loss_meter = AverageMeter()
    per_sample_dnn_time = AverageMeter()
    progress = []
    best_epoch, best_cum_epoch, best_mAP, best_acc, best_cum_mAP = 0, 0, -np.inf, -np.inf, -np.inf
    global_step, epoch = 0, 0
    swa_sign = False
    start_time = time.time()
    exp_dir = exp_dir

    def _save_progress():
        progress.append([epoch, global_step, best_epoch, best_mAP,
                time.time() - start_time])
        with open("%s/progress.pkl" % exp_dir, "wb") as f:
            pickle.dump(progress, f)

    if not isinstance(audio_model, nn.DataParallel):
        audio_model = nn.DataParallel(audio_model)

    audio_model = audio_model.to(device)
    # Set up the optimizer
    audio_trainables = [p for p in audio_model.parameters() if p.requires_grad]
    print('Total parameter number is : {:.3f} million'.format(sum(p.numel() for p in audio_model.parameters()) / 1000000))
    print('Total trainable parameter number is : {:.3f} million'.format(sum(p.numel() for p in audio_trainables) / 1000000))
    trainables = audio_trainables

    optimizer = torch.optim.Adam(trainables, lr, weight_decay=weight_decay, betas=(0.95, 0.999))

    print('now use new scheduler')
    scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, list(range(10, 60)), gamma=1.0)

    epoch += 1

    print("current #steps=%s, #epochs=%s" % (global_step, epoch))
    print("start training...")

    result = np.zeros([n_epochs, 10])
    audio_model.train()
    while epoch < n_epochs + 1:
        begin_time = time.time()
        end_time = time.time()
        audio_model.train()
        print(datetime.datetime.now())

        for i, (audio_input, labels) in enumerate(train_loader):
            # measure data loading time
            B = audio_input.size(0)
            audio_input = audio_input.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            data_time.update(time.time() - end_time)
            per_sample_data_time.update((time.time() - end_time) / audio_input.shape[0])
            dnn_start_time = time.time()

            audio_output = audio_model(audio_input)
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(audio_output, torch.argmax(labels.long(), axis=1))

            # original optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # record loss
            loss_meter.update(loss.item(), B)
            batch_time.update(time.time() - end_time)
            per_sample_time.update((time.time() - end_time)/audio_input.shape[0])
            per_sample_dnn_time.update((time.time() - dnn_start_time)/audio_input.shape[0])

            print_step = global_step % n_print_steps == 0
            early_print_step = epoch == 0 and global_step % (n_print_steps/10) == 0
            print_step = print_step or early_print_step

            if print_step and global_step != 0:
                print('Epoch: [{0}][{1}/{2}]\t'
                  'Per Sample Total Time {per_sample_time.avg:.5f}\t'
                  'Per Sample Data Time {per_sample_data_time.avg:.5f}\t'
                  'Per Sample DNN Time {per_sample_dnn_time.avg:.5f}\t'
                  'Train Loss {loss_meter.val:.4f}\t'.format(
                   epoch, i, len(train_loader), per_sample_time=per_sample_time, per_sample_data_time=per_sample_data_time,
                      per_sample_dnn_time=per_sample_dnn_time, loss_meter=loss_meter), flush=True)
                if np.isnan(loss_meter.avg):
                    print("training diverged...")
                    return

            end_time = time.time()
            global_step += 1

        print('start validation')
        stats, valid_loss = validate(audio_model, test_loader, exp_dir, epoch)
        print('validation finished')

        cum_stats = stats

        cum_mAP = np.mean([stat['AP'] for stat in cum_stats])
        cum_mAUC = np.mean([stat['auc'] for stat in cum_stats])
        cum_acc = np.mean([stat['acc'] for stat in cum_stats])

        mAP = np.mean([stat['AP'] for stat in stats])
        mAUC = np.mean([stat['auc'] for stat in stats])
        acc = np.mean([stat['acc'] for stat in stats])

        middle_ps = [stat['precisions'][int(len(stat['precisions'])/2)] for stat in stats]
        middle_rs = [stat['recalls'][int(len(stat['recalls'])/2)] for stat in stats]
        average_precision = np.mean(middle_ps)
        average_recall = np.mean(middle_rs)

        print("---------------------Epoch {:d} Results---------------------".format(epoch))
        print("ACC: {:.6f}".format(acc))
        print("mAP: {:.6f}".format(mAP))
        print("AUC: {:.6f}".format(mAUC))
        print("Avg Precision: {:.6f}".format(average_precision))
        print("Avg Recall: {:.6f}".format(average_recall))
        print("d_prime: {:.6f}".format(d_prime(mAUC)))
        print("train_loss: {:.6f}".format(loss_meter.avg))
        print("valid_loss: {:.6f}".format(valid_loss))

        result[epoch-1, :] = [mAP, acc, average_precision, average_recall, d_prime(mAUC), loss_meter.avg, valid_loss, cum_mAP, cum_acc, optimizer.param_groups[0]['lr']]

        np.savetxt(exp_dir + '/result.csv', result, delimiter=',')

        if acc > best_acc:
            best_acc = acc
            best_acc_epoch = epoch
            torch.save(audio_model.state_dict(), "%s/models/best_audio_model.pth" % (exp_dir))

        if cum_mAP > best_cum_mAP:
            best_cum_epoch = epoch
            best_cum_mAP = cum_mAP

        if save_model == True:
            torch.save(audio_model.state_dict(), "%s/models/audio_model.%d.pth" % (exp_dir, epoch))

        scheduler.step()

        #print('number of params groups:' + str(len(optimizer.param_groups)))
        print('Epoch-{0} lr: {1}'.format(epoch, optimizer.param_groups[0]['lr']))

        with open(exp_dir + '/stats_' + str(epoch) +'.pickle', 'wb') as handle:
            pickle.dump(stats, handle, protocol=pickle.HIGHEST_PROTOCOL)
        _save_progress()

        finish_time = time.time()
        print('epoch {:d} training time: {:.3f}'.format(epoch, finish_time-begin_time))

        epoch += 1

        batch_time.reset()
        per_sample_time.reset()
        data_time.reset()
        per_sample_data_time.reset()
        loss_meter.reset()
        per_sample_dnn_time.reset()

# %%
def validate(audio_model, val_loader, exp_dir, epoch):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    batch_time = AverageMeter()
    if not isinstance(audio_model, nn.DataParallel):
        audio_model = nn.DataParallel(audio_model)
    audio_model = audio_model.to(device)
    audio_model.eval()

    end = time.time()
    A_predictions = []
    A_targets = []
    A_loss = []
    with torch.no_grad():
        for i, (audio_input, labels) in enumerate(val_loader):
            audio_input = audio_input.to(device)

            # compute output
            audio_output = audio_model(audio_input)
            predictions = audio_output.to('cpu').detach()

            A_predictions.append(predictions)
            A_targets.append(labels)

            # compute the loss
            labels = labels.to(device)
            loss_fn = nn.CrossEntropyLoss()
            # loss without reduction, easy to check per-sample loss
            loss = loss_fn(audio_output, torch.argmax(labels.long(), axis=1))
            A_loss.append(loss.to('cpu').detach())

            batch_time.update(time.time() - end)
            end = time.time()

        audio_output = torch.cat(A_predictions)
        target = torch.cat(A_targets)
        loss = np.mean(A_loss)
        stats = calculate_stats(audio_output, target)

        # save the prediction here
        exp_dir = exp_dir
        if os.path.exists(exp_dir+'/predictions') == False:
            os.mkdir(exp_dir+'/predictions')
            np.savetxt(exp_dir+'/predictions/target.csv', target, delimiter=',')
        np.savetxt(exp_dir+'/predictions/predictions_' + str(epoch) + '.csv', audio_output, delimiter=',')

    return stats, loss

# %%
model='eff_mean'
model_size=0
imagenet_pretrain=False

lr=1e-4
freqm=48
timem=192
mixup=0
batch_size=64

data_dir='/home/jake/repositories/VocalSound-project/data'
exp_dir=f'/home/jake/repositories/VocalSound-project/exp/vocalsound-{model}-{lr}'

CUDA_CACHE_DISABLE=1
n_class=6
n_epochs=30
weight_decay=5e-7
data_train=f'{data_dir}/datafiles/tr.json'
data_val=f'{data_dir}/datafiles/val.json'
label_csv=f'{data_dir}/class_labels_indices_vs.csv'
save_model=True
n_print_steps=100
num_workers=8

# %%
audio_conf = {'num_mel_bins': 128, 'target_length': 512, 'freqm': freqm, 'timem': timem, 'mixup': mixup, 'mode': 'train'}

# %%
print('balanced sampler is not used')
train_loader = torch.utils.data.DataLoader(
    dataloaders.VSDataset(data_train, label_csv=label_csv, audio_conf=audio_conf, raw_wav_mode=False, specaug=True),
    batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=True)
# Out:
# balanced sampler is not used

# %%
val_audio_conf = {'num_mel_bins': 128, 'target_length': 512, 'mixup': 0, 'mode': 'test'}

# %%
val_loader = torch.utils.data.DataLoader(
    dataloaders.VSDataset(data_val, label_csv=label_csv, audio_conf=val_audio_conf, raw_wav_mode=False),
    batch_size=200, shuffle=False, num_workers=num_workers, pin_memory=True)

# %%
if model == 'eff_mean':
    audio_model = models.EffNetMean(label_dim=n_class, level=model_size, pretrain=imagenet_pretrain)
else:
    raise ValueError('Model Unrecognized')
# Out:
# not using imagenet pretrained network

# %%
# start training
if os.path.exists(exp_dir):
    print(f"Deleting existing experiment directory {exp_dir}")
    shutil.rmtree(exp_dir)
print(f"\nCreating experiment directory: {exp_dir}")
os.makedirs(f"{exp_dir}/models")
#with open("%s/args.pkl" % exp_dir, "wb") as f:
#    pickle.dump(args, f)
# Out:
# Deleting existing experiment directory /home/jake/repositories/VocalSound-project/exp/vocalsound-eff_mean-0.0001
#
# Creating experiment directory: /home/jake/repositories/VocalSound-project/exp/vocalsound-eff_mean-0.0001

# %%
print('Now starting training for {:d} epochs'.format(n_epochs))
train(audio_model, train_loader, val_loader, exp_dir,lr,weight_decay,n_epochs,n_print_steps,save_model)
# Out:
# Now starting training for 30 epochs
# cuda
# Total parameter number is : 4.015 million
# Total trainable parameter number is : 4.015 million
# now use new scheduler
# current #steps=0, #epochs=1
# start training...
# 2022-07-15 04:00:40.173127
# Epoch: [1][100/243]	Per Sample Total Time 0.00279	Per Sample Data Time 0.00007	Per Sample DNN Time 0.00272	Train Loss 1.7356
# Epoch: [1][200/243]	Per Sample Total Time 0.00262	Per Sample Data Time 0.00004	Per Sample DNN Time 0.00259	Train Loss 1.7370
# start validation
# validation finished
# ---------------------Epoch 1 Results---------------------
# ACC: 0.166577
# mAP: 0.194957
# AUC: 0.546925
# Avg Precision: 0.181786
# Avg Recall: 0.545565
# d_prime: 0.166729
# train_loss: 1.719457
# valid_loss: 1.793956
# Epoch-1 lr: 0.0001
# epoch 1 training time: 43.212
# 2022-07-15 04:01:23.385169
# Epoch: [2][57/243]	Per Sample Total Time 0.00266	Per Sample Data Time 0.00016	Per Sample DNN Time 0.00250	Train Loss 1.5409
# Epoch: [2][157/243]	Per Sample Total Time 0.00256	Per Sample Data Time 0.00006	Per Sample DNN Time 0.00250	Train Loss 1.5148
# start validation
# validation finished
# ---------------------Epoch 2 Results---------------------
# ACC: 0.261456
# mAP: 0.333725
# AUC: 0.705006
# Avg Precision: 0.245955
# Avg Recall: 0.737421
# d_prime: 0.762055
# train_loss: 1.562889
# valid_loss: 1.764659
# Epoch-2 lr: 0.0001
# epoch 2 training time: 41.960
# 2022-07-15 04:02:05.344714
# Epoch: [3][14/243]	Per Sample Total Time 0.00310	Per Sample Data Time 0.00053	Per Sample DNN Time 0.00257	Train Loss 1.5141
# Epoch: [3][114/243]	Per Sample Total Time 0.00257	Per Sample Data Time 0.00007	Per Sample DNN Time 0.00250	Train Loss 1.4467
# Epoch: [3][214/243]	Per Sample Total Time 0.00255	Per Sample Data Time 0.00004	Per Sample DNN Time 0.00251	Train Loss 1.3340
# start validation
# validation finished
# ---------------------Epoch 3 Results---------------------
# ACC: 0.735310
# mAP: 0.802480
# AUC: 0.937791
# Avg Precision: 0.309371
# Avg Recall: 0.968693
# d_prime: 2.172924
# train_loss: 1.448731
# valid_loss: 1.282066
# Epoch-3 lr: 0.0001
# epoch 3 training time: 42.268
# 2022-07-15 04:02:47.613771
# Epoch: [4][71/243]	Per Sample Total Time 0.00267	Per Sample Data Time 0.00015	Per Sample DNN Time 0.00252	Train Loss 1.3380
# Epoch: [4][171/243]	Per Sample Total Time 0.00257	Per Sample Data Time 0.00006	Per Sample DNN Time 0.00251	Train Loss 1.3166
# start validation
# validation finished
# ---------------------Epoch 4 Results---------------------
# ACC: 0.776819
# mAP: 0.847769
# AUC: 0.950223
# Avg Precision: 0.301725
# Avg Recall: 0.969812
# d_prime: 2.329243
# train_loss: 1.372620
# valid_loss: 1.250614
# Epoch-4 lr: 0.0001
# epoch 4 training time: 42.253
# 2022-07-15 04:03:29.866236
# Epoch: [5][28/243]	Per Sample Total Time 0.00287	Per Sample Data Time 0.00038	Per Sample DNN Time 0.00250	Train Loss 1.3215
# Epoch: [5][128/243]	Per Sample Total Time 0.00255	Per Sample Data Time 0.00009	Per Sample DNN Time 0.00247	Train Loss 1.3414
# Epoch: [5][228/243]	Per Sample Total Time 0.00251	Per Sample Data Time 0.00005	Per Sample DNN Time 0.00246	Train Loss 1.2646
# start validation
# validation finished
# ---------------------Epoch 5 Results---------------------
# ACC: 0.800000
# mAP: 0.872422
# AUC: 0.956343
# Avg Precision: 0.299620
# Avg Recall: 0.976276
# d_prime: 2.417931
# train_loss: 1.336779
# valid_loss: 1.230718
# Epoch-5 lr: 0.0001
# epoch 5 training time: 41.680
# 2022-07-15 04:04:11.546252
# Epoch: [6][85/243]	Per Sample Total Time 0.00265	Per Sample Data Time 0.00010	Per Sample DNN Time 0.00255	Train Loss 1.3754
# Epoch: [6][185/243]	Per Sample Total Time 0.00259	Per Sample Data Time 0.00005	Per Sample DNN Time 0.00254	Train Loss 1.3085
# start validation
# validation finished
# ---------------------Epoch 6 Results---------------------
# ACC: 0.821024
# mAP: 0.882031
# AUC: 0.961517
# Avg Precision: 0.298639
# Avg Recall: 0.983271
# d_prime: 2.501131
# train_loss: 1.309828
# valid_loss: 1.215931
# Epoch-6 lr: 0.0001
# epoch 6 training time: 42.798
# 2022-07-15 04:04:54.344123
# Epoch: [7][42/243]	Per Sample Total Time 0.00276	Per Sample Data Time 0.00020	Per Sample DNN Time 0.00257	Train Loss 1.3456
# Epoch: [7][142/243]	Per Sample Total Time 0.00259	Per Sample Data Time 0.00006	Per Sample DNN Time 0.00253	Train Loss 1.2823
# Epoch: [7][242/243]	Per Sample Total Time 0.00257	Per Sample Data Time 0.00004	Per Sample DNN Time 0.00253	Train Loss 1.3504
# start validation
# validation finished
# ---------------------Epoch 7 Results---------------------
# ACC: 0.819407
# mAP: 0.896683
# AUC: 0.966690
# Avg Precision: 0.296087
# Avg Recall: 0.983281
# d_prime: 2.593986
# train_loss: 1.294072
# valid_loss: 1.206418
# Epoch-7 lr: 0.0001
# epoch 7 training time: 42.489
# 2022-07-15 04:05:36.832642
# Epoch: [8][99/243]	Per Sample Total Time 0.00261	Per Sample Data Time 0.00008	Per Sample DNN Time 0.00253	Train Loss 1.2347
# Epoch: [8][199/243]	Per Sample Total Time 0.00256	Per Sample Data Time 0.00004	Per Sample DNN Time 0.00252	Train Loss 1.2989
# start validation
# validation finished
# ---------------------Epoch 8 Results---------------------
# ACC: 0.859838
# mAP: 0.911528
# AUC: 0.972106
# Avg Precision: 0.292552
# Avg Recall: 0.984353
# d_prime: 2.704943
# train_loss: 1.279059
# valid_loss: 1.175478
# Epoch-8 lr: 0.0001
# epoch 8 training time: 42.273
# 2022-07-15 04:06:19.106208
# Epoch: [9][56/243]	Per Sample Total Time 0.00265	Per Sample Data Time 0.00016	Per Sample DNN Time 0.00249	Train Loss 1.3565
# Epoch: [9][156/243]	Per Sample Total Time 0.00258	Per Sample Data Time 0.00006	Per Sample DNN Time 0.00252	Train Loss 1.3241
# start validation
# validation finished
# ---------------------Epoch 9 Results---------------------
# ACC: 0.854987
# mAP: 0.889904
# AUC: 0.961554
# Avg Precision: 0.287677
# Avg Recall: 0.973040
# d_prime: 2.501754
# train_loss: 1.270480
# valid_loss: 1.186422
# Epoch-9 lr: 0.0001
# epoch 9 training time: 42.189
# 2022-07-15 04:07:01.295646
# Epoch: [10][13/243]	Per Sample Total Time 0.00343	Per Sample Data Time 0.00080	Per Sample DNN Time 0.00263	Train Loss 1.2665
# Epoch: [10][113/243]	Per Sample Total Time 0.00268	Per Sample Data Time 0.00010	Per Sample DNN Time 0.00257	Train Loss 1.2509
# Epoch: [10][213/243]	Per Sample Total Time 0.00265	Per Sample Data Time 0.00005	Per Sample DNN Time 0.00259	Train Loss 1.2319
# start validation
# validation finished
# ---------------------Epoch 10 Results---------------------
# ACC: 0.863073
# mAP: 0.904976
# AUC: 0.970503
# Avg Precision: 0.292161
# Avg Recall: 0.986528
# d_prime: 2.670369
# train_loss: 1.262234
# valid_loss: 1.174149
# Epoch-10 lr: 0.0001
# epoch 10 training time: 43.673
# 2022-07-15 04:07:44.968255
# Epoch: [11][70/243]	Per Sample Total Time 0.00264	Per Sample Data Time 0.00014	Per Sample DNN Time 0.00249	Train Loss 1.2990
# Epoch: [11][170/243]	Per Sample Total Time 0.00257	Per Sample Data Time 0.00006	Per Sample DNN Time 0.00251	Train Loss 1.3140
# start validation
# validation finished
# ---------------------Epoch 11 Results---------------------
# ACC: 0.850674
# mAP: 0.911995
# AUC: 0.974590
# Avg Precision: 0.293748
# Avg Recall: 0.988659
# d_prime: 2.761965
# train_loss: 1.255806
# valid_loss: 1.179028
# Epoch-11 lr: 0.0001
# epoch 11 training time: 42.392
# 2022-07-15 04:08:27.360414
# Epoch: [12][27/243]	Per Sample Total Time 0.00282	Per Sample Data Time 0.00031	Per Sample DNN Time 0.00251	Train Loss 1.3162
# Epoch: [12][127/243]	Per Sample Total Time 0.00254	Per Sample Data Time 0.00007	Per Sample DNN Time 0.00247	Train Loss 1.2247
# Epoch: [12][227/243]	Per Sample Total Time 0.00251	Per Sample Data Time 0.00004	Per Sample DNN Time 0.00247	Train Loss 1.2422
# start validation
# validation finished
# ---------------------Epoch 12 Results---------------------
# ACC: 0.858221
# mAP: 0.910606
# AUC: 0.972867
# Avg Precision: 0.291393
# Avg Recall: 0.987594
# d_prime: 2.721953
# train_loss: 1.251704
# valid_loss: 1.178074
# Epoch-12 lr: 0.0001
# epoch 12 training time: 41.747
# 2022-07-15 04:09:09.107704
# Epoch: [13][84/243]	Per Sample Total Time 0.00259	Per Sample Data Time 0.00011	Per Sample DNN Time 0.00247	Train Loss 1.1909
# Epoch: [13][184/243]	Per Sample Total Time 0.00252	Per Sample Data Time 0.00005	Per Sample DNN Time 0.00247	Train Loss 1.1917
# start validation
# validation finished
# ---------------------Epoch 13 Results---------------------
# ACC: 0.859299
# mAP: 0.905970
# AUC: 0.971789
# Avg Precision: 0.289622
# Avg Recall: 0.985976
# d_prime: 2.697992
# train_loss: 1.244611
# valid_loss: 1.175327
# Epoch-13 lr: 0.0001
# epoch 13 training time: 41.673
# 2022-07-15 04:09:50.779813
# Epoch: [14][41/243]	Per Sample Total Time 0.00271	Per Sample Data Time 0.00020	Per Sample DNN Time 0.00251	Train Loss 1.3164
# Epoch: [14][141/243]	Per Sample Total Time 0.00254	Per Sample Data Time 0.00006	Per Sample DNN Time 0.00248	Train Loss 1.2575
# Epoch: [14][241/243]	Per Sample Total Time 0.00251	Per Sample Data Time 0.00004	Per Sample DNN Time 0.00248	Train Loss 1.2139
# start validation
# validation finished
# ---------------------Epoch 14 Results---------------------
# ACC: 0.872776
# mAP: 0.905863
# AUC: 0.969594
# Avg Precision: 0.288751
# Avg Recall: 0.982749
# d_prime: 2.651451
# train_loss: 1.241266
# valid_loss: 1.170845
# Epoch-14 lr: 0.0001
# epoch 14 training time: 41.758
# 2022-07-15 04:10:32.537698
# Epoch: [15][98/243]	Per Sample Total Time 0.00257	Per Sample Data Time 0.00009	Per Sample DNN Time 0.00248	Train Loss 1.2474
# Epoch: [15][198/243]	Per Sample Total Time 0.00252	Per Sample Data Time 0.00005	Per Sample DNN Time 0.00247	Train Loss 1.1836
# start validation
# validation finished
# ---------------------Epoch 15 Results---------------------
# ACC: 0.872237
# mAP: 0.910845
# AUC: 0.976775
# Avg Precision: 0.291025
# Avg Recall: 0.991911
# d_prime: 2.816106
# train_loss: 1.238472
# valid_loss: 1.163436
# Epoch-15 lr: 0.0001
# epoch 15 training time: 41.648
# 2022-07-15 04:11:14.186614
# Epoch: [16][55/243]	Per Sample Total Time 0.00268	Per Sample Data Time 0.00018	Per Sample DNN Time 0.00250	Train Loss 1.2097
# Epoch: [16][155/243]	Per Sample Total Time 0.00255	Per Sample Data Time 0.00007	Per Sample DNN Time 0.00248	Train Loss 1.2639
# start validation
# validation finished
# ---------------------Epoch 16 Results---------------------
# ACC: 0.878167
# mAP: 0.916602
# AUC: 0.977567
# Avg Precision: 0.290297
# Avg Recall: 0.991380
# d_prime: 2.836778
# train_loss: 1.240092
# valid_loss: 1.158804
# Epoch-16 lr: 0.0001
# epoch 16 training time: 41.850
# 2022-07-15 04:11:56.036210
# Epoch: [17][12/243]	Per Sample Total Time 0.00328	Per Sample Data Time 0.00071	Per Sample DNN Time 0.00256	Train Loss 1.2361
# Epoch: [17][112/243]	Per Sample Total Time 0.00259	Per Sample Data Time 0.00008	Per Sample DNN Time 0.00251	Train Loss 1.1990
# Epoch: [17][212/243]	Per Sample Total Time 0.00255	Per Sample Data Time 0.00005	Per Sample DNN Time 0.00251	Train Loss 1.1957
# start validation
# validation finished
# ---------------------Epoch 17 Results---------------------
# ACC: 0.880323
# mAP: 0.921187
# AUC: 0.978548
# Avg Precision: 0.289981
# Avg Recall: 0.989754
# d_prime: 2.863267
# train_loss: 1.230207
# valid_loss: 1.154275
# Epoch-17 lr: 0.0001
# epoch 17 training time: 42.351
# 2022-07-15 04:12:38.386729
# Epoch: [18][69/243]	Per Sample Total Time 0.00264	Per Sample Data Time 0.00012	Per Sample DNN Time 0.00252	Train Loss 1.1527
# Epoch: [18][169/243]	Per Sample Total Time 0.00255	Per Sample Data Time 0.00005	Per Sample DNN Time 0.00250	Train Loss 1.2028
# start validation
# validation finished
# ---------------------Epoch 18 Results---------------------
# ACC: 0.870081
# mAP: 0.914703
# AUC: 0.975563
# Avg Precision: 0.289774
# Avg Recall: 0.985985
# d_prime: 2.785559
# train_loss: 1.228355
# valid_loss: 1.164515
# Epoch-18 lr: 0.0001
# epoch 18 training time: 41.977
# 2022-07-15 04:13:20.363455
# Epoch: [19][26/243]	Per Sample Total Time 0.00285	Per Sample Data Time 0.00036	Per Sample DNN Time 0.00249	Train Loss 1.3273
# Epoch: [19][126/243]	Per Sample Total Time 0.00257	Per Sample Data Time 0.00008	Per Sample DNN Time 0.00249	Train Loss 1.2475
# Epoch: [19][226/243]	Per Sample Total Time 0.00255	Per Sample Data Time 0.00004	Per Sample DNN Time 0.00251	Train Loss 1.2372
# start validation
# validation finished
# ---------------------Epoch 19 Results---------------------
# ACC: 0.880863
# mAP: 0.917080
# AUC: 0.978390
# Avg Precision: 0.289701
# Avg Recall: 0.990295
# d_prime: 2.858934
# train_loss: 1.229988
# valid_loss: 1.155699
# Epoch-19 lr: 0.0001
# epoch 19 training time: 42.283
# 2022-07-15 04:14:02.646208
# Epoch: [20][83/243]	Per Sample Total Time 0.00258	Per Sample Data Time 0.00010	Per Sample DNN Time 0.00249	Train Loss 1.1518
# Epoch: [20][183/243]	Per Sample Total Time 0.00252	Per Sample Data Time 0.00005	Per Sample DNN Time 0.00247	Train Loss 1.2060
# start validation
# validation finished
# ---------------------Epoch 20 Results---------------------
# ACC: 0.869003
# mAP: 0.917509
# AUC: 0.977671
# Avg Precision: 0.289509
# Avg Recall: 0.989212
# d_prime: 2.839558
# train_loss: 1.223426
# valid_loss: 1.153640
# Epoch-20 lr: 0.0001
# epoch 20 training time: 41.433
# 2022-07-15 04:14:44.078908
# Epoch: [21][40/243]	Per Sample Total Time 0.00267	Per Sample Data Time 0.00021	Per Sample DNN Time 0.00247	Train Loss 1.1893
# Epoch: [21][140/243]	Per Sample Total Time 0.00252	Per Sample Data Time 0.00006	Per Sample DNN Time 0.00246	Train Loss 1.2616
# Epoch: [21][240/243]	Per Sample Total Time 0.00250	Per Sample Data Time 0.00004	Per Sample DNN Time 0.00247	Train Loss 1.3085
# start validation
# validation finished
# ---------------------Epoch 21 Results---------------------
# ACC: 0.878706
# mAP: 0.927304
# AUC: 0.980542
# Avg Precision: 0.290694
# Avg Recall: 0.991373
# d_prime: 2.920450
# train_loss: 1.224303
# valid_loss: 1.153022
# Epoch-21 lr: 0.0001
# epoch 21 training time: 41.524
# 2022-07-15 04:15:25.603129
# Epoch: [22][97/243]	Per Sample Total Time 0.00265	Per Sample Data Time 0.00010	Per Sample DNN Time 0.00255	Train Loss 1.2724
# Epoch: [22][197/243]	Per Sample Total Time 0.00257	Per Sample Data Time 0.00005	Per Sample DNN Time 0.00252	Train Loss 1.1946
# start validation
# validation finished
# ---------------------Epoch 22 Results---------------------
# ACC: 0.879245
# mAP: 0.915560
# AUC: 0.976564
# Avg Precision: 0.288989
# Avg Recall: 0.988668
# d_prime: 2.810678
# train_loss: 1.220787
# valid_loss: 1.158816
# Epoch-22 lr: 0.0001
# epoch 22 training time: 42.112
# 2022-07-15 04:16:07.715514
# Epoch: [23][54/243]	Per Sample Total Time 0.00262	Per Sample Data Time 0.00015	Per Sample DNN Time 0.00247	Train Loss 1.2573
# Epoch: [23][154/243]	Per Sample Total Time 0.00252	Per Sample Data Time 0.00005	Per Sample DNN Time 0.00247	Train Loss 1.2391
# start validation
# validation finished
# ---------------------Epoch 23 Results---------------------
# ACC: 0.884097
# mAP: 0.922583
# AUC: 0.979425
# Avg Precision: 0.290149
# Avg Recall: 0.990293
# d_prime: 2.887857
# train_loss: 1.218529
# valid_loss: 1.152263
# Epoch-23 lr: 0.0001
# epoch 23 training time: 42.210
# 2022-07-15 04:16:49.925151
# Epoch: [24][11/243]	Per Sample Total Time 0.00336	Per Sample Data Time 0.00080	Per Sample DNN Time 0.00256	Train Loss 1.2178
# Epoch: [24][111/243]	Per Sample Total Time 0.00261	Per Sample Data Time 0.00009	Per Sample DNN Time 0.00252	Train Loss 1.2064
# Epoch: [24][211/243]	Per Sample Total Time 0.00256	Per Sample Data Time 0.00005	Per Sample DNN Time 0.00252	Train Loss 1.2027
# start validation
# validation finished
# ---------------------Epoch 24 Results---------------------
# ACC: 0.883558
# mAP: 0.920985
# AUC: 0.980611
# Avg Precision: 0.290055
# Avg Recall: 0.992459
# d_prime: 2.922526
# train_loss: 1.212420
# valid_loss: 1.154511
# Epoch-24 lr: 0.0001
# epoch 24 training time: 42.278
# 2022-07-15 04:17:32.203444
# Epoch: [25][68/243]	Per Sample Total Time 0.00261	Per Sample Data Time 0.00014	Per Sample DNN Time 0.00246	Train Loss 1.1677
# Epoch: [25][168/243]	Per Sample Total Time 0.00252	Per Sample Data Time 0.00006	Per Sample DNN Time 0.00246	Train Loss 1.2714
# start validation
# validation finished
# ---------------------Epoch 25 Results---------------------
# ACC: 0.887871
# mAP: 0.933227
# AUC: 0.981435
# Avg Precision: 0.292352
# Avg Recall: 0.990836
# d_prime: 2.947689
# train_loss: 1.211807
# valid_loss: 1.150091
# Epoch-25 lr: 0.0001
# epoch 25 training time: 41.560
# 2022-07-15 04:18:13.763427
# Epoch: [26][25/243]	Per Sample Total Time 0.00284	Per Sample Data Time 0.00036	Per Sample DNN Time 0.00248	Train Loss 1.2420
# Epoch: [26][125/243]	Per Sample Total Time 0.00254	Per Sample Data Time 0.00008	Per Sample DNN Time 0.00246	Train Loss 1.1841
# Epoch: [26][225/243]	Per Sample Total Time 0.00252	Per Sample Data Time 0.00004	Per Sample DNN Time 0.00247	Train Loss 1.2530
# start validation
# validation finished
# ---------------------Epoch 26 Results---------------------
# ACC: 0.884636
# mAP: 0.923442
# AUC: 0.979594
# Avg Precision: 0.289014
# Avg Recall: 0.989228
# d_prime: 2.892688
# train_loss: 1.211175
# valid_loss: 1.148981
# Epoch-26 lr: 0.0001
# epoch 26 training time: 41.623
# 2022-07-15 04:18:55.386152
# Epoch: [27][82/243]	Per Sample Total Time 0.00264	Per Sample Data Time 0.00012	Per Sample DNN Time 0.00252	Train Loss 1.2659
# Epoch: [27][182/243]	Per Sample Total Time 0.00255	Per Sample Data Time 0.00006	Per Sample DNN Time 0.00249	Train Loss 1.1992
# start validation
# validation finished
# ---------------------Epoch 27 Results---------------------
# ACC: 0.891105
# mAP: 0.930947
# AUC: 0.983658
# Avg Precision: 0.291806
# Avg Recall: 0.996231
# d_prime: 3.020697
# train_loss: 1.212051
# valid_loss: 1.148340
# Epoch-27 lr: 0.0001
# epoch 27 training time: 41.868
# 2022-07-15 04:19:37.254010
# Epoch: [28][39/243]	Per Sample Total Time 0.00278	Per Sample Data Time 0.00022	Per Sample DNN Time 0.00256	Train Loss 1.2927
# Epoch: [28][139/243]	Per Sample Total Time 0.00256	Per Sample Data Time 0.00006	Per Sample DNN Time 0.00249	Train Loss 1.2045
# Epoch: [28][239/243]	Per Sample Total Time 0.00252	Per Sample Data Time 0.00004	Per Sample DNN Time 0.00248	Train Loss 1.1612
# start validation
# validation finished
# ---------------------Epoch 28 Results---------------------
# ACC: 0.891105
# mAP: 0.939687
# AUC: 0.983047
# Avg Precision: 0.290654
# Avg Recall: 0.993529
# d_prime: 2.999805
# train_loss: 1.211118
# valid_loss: 1.147217
# Epoch-28 lr: 0.0001
# epoch 28 training time: 41.715
# 2022-07-15 04:20:18.969026
# Epoch: [29][96/243]	Per Sample Total Time 0.00258	Per Sample Data Time 0.00010	Per Sample DNN Time 0.00248	Train Loss 1.1672
# Epoch: [29][196/243]	Per Sample Total Time 0.00254	Per Sample Data Time 0.00005	Per Sample DNN Time 0.00249	Train Loss 1.2566
# start validation
# validation finished
# ---------------------Epoch 29 Results---------------------
# ACC: 0.897035
# mAP: 0.931759
# AUC: 0.983348
# Avg Precision: 0.289866
# Avg Recall: 0.992997
# d_prime: 3.009997
# train_loss: 1.207640
# valid_loss: 1.142979
# Epoch-29 lr: 0.0001
# epoch 29 training time: 42.257
# 2022-07-15 04:21:01.226869
# Epoch: [30][53/243]	Per Sample Total Time 0.00270	Per Sample Data Time 0.00018	Per Sample DNN Time 0.00252	Train Loss 1.2112
# Epoch: [30][153/243]	Per Sample Total Time 0.00259	Per Sample Data Time 0.00007	Per Sample DNN Time 0.00253	Train Loss 1.1900
# start validation
# validation finished
# ---------------------Epoch 30 Results---------------------
# ACC: 0.883019
# mAP: 0.934990
# AUC: 0.981733
# Avg Precision: 0.292092
# Avg Recall: 0.992986
# d_prime: 2.957017
# train_loss: 1.204020
# valid_loss: 1.154734
# Epoch-30 lr: 0.0001
# epoch 30 training time: 42.381

# %%
# test on the test set and sub-test set, model selected on the validation set
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
sd = torch.load(exp_dir + '/models/best_audio_model.pth', map_location=device)
audio_model = torch.nn.DataParallel(audio_model)
audio_model.load_state_dict(sd)
# Out:
# <All keys matched successfully>

# %%
all_res = []

# %%
# best model on the validation set, repeat to confirm
stats, _ = validate(audio_model, val_loader, exp_dir, 'valid_set')
# note it is NOT mean of class-wise accuracy
val_acc = stats[0]['acc']
val_mAUC = np.mean([stat['auc'] for stat in stats])
print('---------------evaluate on the validation set---------------')
print("Accuracy: {:.6f}".format(val_acc))
all_res.append(val_acc)
# Out:
# ---------------evaluate on the validation set---------------
# Accuracy: 0.897035

# %%
# test the model on the evaluation set
data_eval_list = ['te.json', 'subtest/te_age1.json', 'subtest/te_age2.json', 'subtest/te_age3.json', 'subtest/te_female.json', 'subtest/te_male.json']
eval_name_list = ['all_test', 'test age 18-25', 'test age 26-48', 'test age 49-80', 'test female', 'test male']

# %%
data_dir = '/'.join(data_val.split('/')[:-1])
for idx, cur_eval in enumerate(data_eval_list):
    cur_eval = data_dir + '/' + cur_eval
    eval_loader = torch.utils.data.DataLoader(
        dataloaders.VSDataset(cur_eval, label_csv=label_csv, audio_conf=val_audio_conf),
        batch_size=batch_size*2, shuffle=False, num_workers=num_workers, pin_memory=True)
    stats, _ = validate(audio_model, eval_loader, exp_dir, eval_name_list[idx])
    eval_acc = stats[0]['acc']
    all_res.append(eval_acc)
    print('---------------evaluate on {:s}---------------'.format(eval_name_list[idx]))
    print("Accuracy: {:.6f}".format(eval_acc))
# Out:
# ---------------evaluate on all_test---------------
# Accuracy: 0.908939
# ---------------evaluate on test age 18-25---------------
# Accuracy: 0.919283
# ---------------evaluate on test age 26-48---------------
# Accuracy: 0.905997
# ---------------evaluate on test age 49-80---------------
# Accuracy: 0.902299
# ---------------evaluate on test female---------------
# Accuracy: 0.918427
# ---------------evaluate on test male---------------
# Accuracy: 0.899946

# %%
all_res = np.array(all_res)
all_res = all_res.reshape([1, all_res.shape[0]])
np.savetxt(exp_dir + '/all_eval_result.csv', all_res, header=','.join(['validation'] + eval_name_list))
